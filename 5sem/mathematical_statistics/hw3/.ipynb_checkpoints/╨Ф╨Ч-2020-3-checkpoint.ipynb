# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats
pd.set_option('max_colwidth', 80)
np.random.seed(5)

# %%
students = pd.read_excel("310.xlsx")
students=students.drop('почта', axis = 1)
students.insert(1,'Сравнить', np.random.choice(['Время от первых симптомов до выздоровления у мужчин и женщин',
                                                'Время от первых симптомов до выздоровления до 60 лет и после 60 лет',
                                                'Время от первых симптомов до выздоровления до 45 лет и после 45 лет',
                                                'возраст в Китае и в Японии',
                                                'возраст в Китае и в Европе',
                                                'возраст в Сингапуре и в Южной Корее',
                                                 'Инкубационный период до 45 лет и после 45 лет',
'Инкубационный период в Китае и в остальной Азии', 
'возраст  мужчин и женщин'],size = len(students)))
students
# Out:
#                                ФИО  \
# 0       Арсланова Алина Рустямовна
# 1      Афиногенова Ирина Андреевна
# 2     Винницкий Всеволод Сергеевич
# 3   Григорьев Степан Александрович
# 4         Дерюгин Максим Сергеевич
# 5        Карковский Остап Игоревич
# 6        Кармацких Ирина Вадимовна
# 7         Кутасин Кирилл Андреевич
# 8            Лебедь Иван Сергеевич
# 9      Лобанова Валерия Алексеевна
# 10   Локтев Дмитрий Константинович
# 11      Мартынов Николай Сергеевич
# 12         Намит Максим Михайлович
# 13           Попова Анна Романовна
# 14      Сибгатуллин Артур Петрович
# 15       Сокунов Дмитрий Антонович
# 16       Стрельчик Роман Семёнович
# 17       Тимофеев Кирилл Сергеевич
# 18       Устинов Никита Евгеньевич
# 19          Федотов Иван Андреевич
# 20        Фирсов Михаил Михайлович
# 21       Чухнов Антон Владимирович
# 22           Шиканян Лев Романович
#
#                                                                Сравнить
# ...

# %% [markdown]
# ### Перед сравнением проверить выборки на нормальность и применить все допустимые критерии (их будет или два или один). Пример содержится в файле KoronaIndividual_withsuggestions.ipynb
