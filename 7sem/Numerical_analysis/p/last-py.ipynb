# %%
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np

# %%
def run_prog(M):
    result = !./a.out 1  10 $M 0.1
    
    result[0] = [float(i) for i in result[0].split()]
    result[1] = [float(i) for i in result[1].split()]
    return result

# %%
def determ_stabilisation():
    #return stabilizsation step and lost mass
    eps = 0.02
    step = 1
    previous= -1
    res = run_prog(0)
    initial_mass = np.linalg.norm(res[0])
    while True:
        res = run_prog(step)
        if abs(max(res[0]) - min(res[0])) < eps and abs(max(res[1]) - min(res[1])) < eps:
            return step, np.linalg.norm(res[0]) - initial_mass
        step+=1
        print(step, )

# %%
def draw(first, second):
    plt.figure(num=None, figsize=(20, 8), dpi=80, facecolor='w', edgecolor='k')

    plt.plot([0.1*i for i in range(len(first))], first, "g")
    plt.plot([0.1*i for i in range(len(second))], second, "r")
    plt.legend(["Плотность", "Скорость"], prop={"size":20})
    plt.show()

# %%
# !g++ razr-for-pic.cpp -O3 -march=native -ffast-math

# %%
r = run_prog(32)

# %%
draw(r[0], r[1])
#print("{:e}".format(determ_diff_mass(10000)))

# %%
determ_stabilisation()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-84b64a000e58> in <module>
# ----> 1 determ_stabilisation()
#
# <ipython-input-30-5ae1daa718bb> in determ_stabilisation()
#       4     step = 1
#       5     previous= -1
# ----> 6     res = run_prog(0)
#       7     initial_mass = np.linalg.norm(res[0])
#       8     while True:
#
# <ipython-input-29-9a761760dec4> in run_prog(M)
#       2     result = get_ipython().getoutput('./a.out 1  10 $M 0.1')
#       3
# ----> 4     result[0] = [float(i) for i in result[0].split()]
#       5     result[1] = [float(i) for i in result[1].split()]
#       6     return result
#
# <ipython-input-29-9a761760dec4> in <listcomp>(.0)
#       2     result = get_ipython().getoutput('./a.out 1  10 $M 0.1')
#       3
# ----> 4     result[0] = [float(i) for i in result[0].split()]
#       5     result[1] = [float(i) for i in result[1].split()]
#       6     return result
#
# ValueError: could not convert string to float: 'double'

# %%
r = run_prog(2791)

# %%
draw(r[0], r[1])

# %%
draw(r[0], r[1])
